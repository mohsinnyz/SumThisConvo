# %%
# !git clone https://github.com/mohsinnyz/SumThisConvo.git
# %cd SumThisConvo

# %%
# !pip install -r requirements.txt -q

# Core training libs (pinned versions for Gemma stability)
# !pip install -q bitsandbytes==0.43.0
# !pip install -q transformers==4.38.0
# !pip install -q accelerate==0.27.2
# !pip install -q peft==0.9.0
# !pip install -q trl==0.7.6

# DVC + remote type (change if you use S3)
# !pip install -q dvc dvc[gdrive]

# %%
from huggingface_hub import login
login()

# %%
# !dvc pull

# %%
# !python src/train.py \
    --trust-remote-code \
    --epochs=1 \
    --batch-size=2 \
    --mlflow-experiment="SumThisConvo-Colab-Run" \
    --push-to-hub \
    --hub-repo-id="mohsinnyz/SumThisConvo-gemma-2b"
